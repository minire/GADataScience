# %% [markdown]
# ## AirBnB Data evaluation
#
# Let's take a look at the data first

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
url = '/Users/jennawhite/documents/wild_west/abnb_project/data/train_users_2.csv'

bnb = pd.read_csv(url, index_col='id')
bnb.shape
# Out:
# (213451, 15)

# %%
bnb.columns
# Out:
# Index([u'date_account_created', u'timestamp_first_active',
#        u'date_first_booking', u'gender', u'age', u'signup_method',
#        u'signup_flow', u'language', u'affiliate_channel',
#        u'affiliate_provider', u'first_affiliate_tracked', u'signup_app',
#        u'first_device_type', u'first_browser', u'country_destination'],
#       dtype='object')

# %%
bnb.first_affiliate_tracked.value_counts()
# Out:
# untracked        109232
# linked            46287
# omg               43982
# tracked-other      6156
# product            1556
# marketing           139
# local ops            34
# Name: first_affiliate_tracked, dtype: int64

# %%
bnb = pd.concat([bnb,pd.get_dummies(bnb['first_affiliate_tracked'],prefix='channel_')],axis=1)
bnb.head()
# Out:
#            date_account_created  timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28          20090319043255                NaN
# 820tgsjxq7           2011-05-25          20090523174809                NaN
# 4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#                gender   age signup_method  signup_flow language  \
# id
# gxn3p5htnn  -unknown-   NaN      facebook            0       en
# 820tgsjxq7       MALE  38.0      facebook            0       en
# 4ft3gnwmtx     FEMALE  56.0         basic            3       en
# bjjt8pjhuk     FEMALE  42.0      facebook            0       en
# 87mebub9p4  -unknown-  41.0         basic            0       en
#
#            affiliate_channel affiliate_provider         ...          \
# id                                                      ...
# gxn3p5htnn            direct             direct         ...
# 820tgsjxq7               seo             google         ...
# 4ft3gnwmtx            direct             direct         ...
# bjjt8pjhuk            direct             direct         ...
# 87mebub9p4            direct             direct         ...
#
#            first_device_type first_browser country_destination  \
# id
# gxn3p5htnn       Mac Desktop        Chrome                 NDF
# 820tgsjxq7       Mac Desktop        Chrome                 NDF
# 4ft3gnwmtx   Windows Desktop            IE                  US
# bjjt8pjhuk       Mac Desktop       Firefox               other
# 87mebub9p4       Mac Desktop        Chrome                  US
#
#            channel__linked channel__local ops  channel__marketing  \
# id
# gxn3p5htnn             0.0                0.0                 0.0
# 820tgsjxq7             0.0                0.0                 0.0
# 4ft3gnwmtx             0.0                0.0                 0.0
# bjjt8pjhuk             0.0                0.0                 0.0
# 87mebub9p4             0.0                0.0                 0.0
#
#             channel__omg  channel__product  channel__tracked-other  \
# id
# gxn3p5htnn           0.0               0.0                     0.0
# 820tgsjxq7           0.0               0.0                     0.0
# 4ft3gnwmtx           0.0               0.0                     0.0
# bjjt8pjhuk           0.0               0.0                     0.0
# 87mebub9p4           0.0               0.0                     0.0
#
#             channel__untracked
# id
# gxn3p5htnn                 1.0
# 820tgsjxq7                 1.0
# 4ft3gnwmtx                 1.0
# bjjt8pjhuk                 1.0
# 87mebub9p4                 1.0
#
# [5 rows x 22 columns]

# %%
bnb.shape
# Out:
# (213451, 22)

# %%
pd.concat([bnb, a],axis=1)
# Out:
#            date_account_created  timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28          20090319043255                NaN
# 820tgsjxq7           2011-05-25          20090523174809                NaN
# 4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 87mebub9p4           2010-09-14          20091208061105         2010-02-18
# osr2jwljor           2010-01-01          20100101215619         2010-01-02
# lsw9q7uk0j           2010-01-02          20100102012558         2010-01-05
# 0d01nltbrs           2010-01-03          20100103191905         2010-01-13
# a1vcnhxeij           2010-01-04          20100104004211         2010-07-29
# 6uh8zyj2gn           2010-01-04          20100104023758         2010-01-04
facebook            0       en
# 4ft3gnwmtx     FEMALE  56.0         basic            3       en
# bjjt8pjhuk     FEMALE  42.0      facebook            0       en
# 87mebub9p4  -unknown-  41.0         basic            0       en
# osr2jwljor  -unknown-   NaN         basic            0       en
# lsw9q7uk0j     FEMALE  46.0         basic            0       en
# 0d01nltbrs     FEMALE  47.0         basic            0       en
# a1vcnhxeij     FEMALE  50.0         basic            0       en
# 6uh8zyj2gn  -unknown-  46.0         basic            0       en
# yuuqmid2rp     FEMALE  36.0         basic            0       en
# om1ss59ys8     FEMALE  47.0         basic            0       en
# k6np330cm1  -unknown-   NaN         basic            0       en
# dy3rgx56cu     FEMALE  37.0         basic            0       en
# ju3h98ch3w     FEMALE  36.0         basic            0       en
# v4d5rl22px     FEMALE  33.0         basic            0       en
# 2dwbwkx056  -unknown-   NaN         basic            0       en
# frhre329au  -unknown-  31.0         basic            0       en
# cxlg85pg1r  -unknown-   NaN         basic            0       en
# gdka1q5ktd     FEMALE  29.0         basic            0       en
# qdubonn3uk  -unknown-   NaN         basic            0       en
# qsibmuz9sx       MALE  30.0         basic            0       en
# 80f7dwscrn  -unknown-  40.0         basic            0       en
# jha93x042q  -unknown-   NaN         basic            0       en
# 7i49vnuav6     FEMALE  40.0         basic            0       en
# al8bcetz0g     FEMALE  26.0         basic            0       en
# bjg0m5otl3  -unknown-   NaN         basic            0       en
# hfrl5gle36     FEMALE  32.0         basic            0       en
# tp6x3md0n4  -unknown-  35.0         basic            0       en
# hql77nu2lk  -unknown-  37.0         basic            0       en
# ...               ...   ...           ...          ...      ...
# c98s3h7kgj  -unknown-   NaN         basic            0       en
# ytmpiwb8hj  -unknown-   NaN         basic            0       en
# 3dx1jk6yk2     FEMALE  20.0      facebook           25       en
# hcfj07iowv     FEMALE  32.0      facebook            0       en
# l1f71f9vsj     FEMALE  30.0      facebook            0       en
# 15bj4ahmhf  -unknown-   NaN         basic            0       en
# qwpybxfjdl  -unknown-   NaN         basic            0       en
# k4t61wuvyq  -unknown-   NaN         basic           23       en
# mhh7b52z44  -unknown-   NaN         basic           25       en
# 79wk7k2k5t  -unknown-  19.0         basic            0       en
# ftwmocvwlq  -unknown-   NaN         basic            0       en
# rg7ayg1tob       MALE  31.0      facebook            0       en
# 2f24umzkuv  -unknown-   NaN         basic            0       en
# or77n2ojuj  -unknown-   NaN         basic            0       en
# 0a5bnb9bs4  -unknown-   NaN         basic            0       en
# 6fzrn49sfn  -unknown-   NaN         basic           25       en
# r0jq0devgy  -unknown-   NaN         basic           23       en
# v5lq9bj8gv  -unknown-   NaN         basic           25       en
# msucfwmlzc       MALE  43.0         basic            0       en
# 04y8115avm     FEMALE  24.0         basic           25       en
# omlc9iku7t     FEMALE  34.0         basic            0       en
# rf0ay567js  -unknown-   NaN         basic            0       en
# 0k26r3mir0     FEMALE  36.0         basic            0       en
# 40o1ivh6cb  -unknown-   NaN         basic            0       en
# qbxza0xojf     FEMALE  23.0         basic            0       en
# zxodksqpep       MALE  32.0         basic            0       en
# mhewnxesx9  -unknown-   NaN         basic            0       en
# 6o3arsjbb4  -unknown-  32.0         basic            0       en
# jh95kwisub  -unknown-   NaN         basic           25       en
# nw9fwlyb5f  -unknown-   NaN         basic           25       en
#
#            affiliate_channel affiliate_provider         ...          \
# id                                                      ...
# gxn3p5htnn            direct             direct         ...
# 820tgsjxq7               seo             google         ...
# 4ft3gnwmtx            direct             direct         ...
# bjjt8pjhuk            direct             direct         ...
# 87mebub9p4            direct             direct         ...
# osr2jwljor             other              other         ...
# lsw9q7uk0j             other         craigslist         ...
# 0d01nltbrs            direct             direct         ...
# a1vcnhxeij             other         craigslist         ...
# 6uh8zyj2gn             other         craigslist         ...
# yuuqmid2rp             other         craigslist         ...
# om1ss59ys8             other         craigslist         ...
# k6np330cm1            direct             direct         ...
# dy3rgx56cu             other         craigslist         ...
# ju3h98ch3w             other         craigslist         ...
# v4d5rl22px            direct             direct         ...
# 2dwbwkx056             other         craigslist         ...
# frhre329au             other         craigslist         ...
# cxlg85pg1r               seo           facebook         ...
# gdka1q5ktd            direct             direct         ...
# qdubonn3uk            direct             direct         ...
# qsibmuz9sx            direct             direct         ...
# 80f7dwscrn               seo             google         ...
# jha93x042q             other         craigslist         ...
# 7i49vnuav6               seo             google         ...
# al8bcetz0g             other         craigslist         ...
# bjg0m5otl3             other              other         ...
# hfrl5gle36             other         craigslist         ...
# tp6x3md0n4            direct             direct         ...
# hql77nu2lk            direct             direct         ...
# ...                      ...                ...         ...
# c98s3h7kgj            direct             direct         ...
# ytmpiwb8hj            direct             direct         ...
# 3dx1jk6yk2            direct             direct         ...
# hcfj07iowv            direct             direct         ...
# l1f71f9vsj            direct             direct         ...
# 15bj4ahmhf            direct             direct         ...
# qwpybxfjdl            direct             direct         ...
# k4t61wuvyq            direct             direct         ...
# mhh7b52z44            direct             direct         ...
# 79wk7k2k5t            direct             direct         ...
# ftwmocvwlq            direct             direct         ...
# rg7ayg1tob            direct             direct         ...
# 2f24umzkuv         sem-brand             google         ...
# or77n2ojuj               seo           facebook         ...
# 0a5bnb9bs4               seo             google         ...
# 6fzrn49sfn            direct             direct         ...
# r0jq0devgy            direct             direct         ...
# v5lq9bj8gv            direct             direct         ...
# msucfwmlzc            direct             direct         ...
# 04y8115avm            direct             direct         ...
# omlc9iku7t            direct             direct         ...
# rf0ay567js         sem-brand             google         ...
# 0k26r3mir0         sem-brand             google         ...
# 40o1ivh6cb            direct             direct         ...
# qbxza0xojf         sem-brand             google         ...
# zxodksqpep         sem-brand             google         ...
# mhewnxesx9            direct             direct         ...
# 6o3arsjbb4            direct             direct         ...
# jh95kwisub             other              other         ...
# nw9fwlyb5f            direct             direct         ...
#
#            first_device_type  first_browser country_destination  \
# id
# gxn3p5htnn       Mac Desktop         Chrome                 NDF
# 820tgsjxq7       Mac Desktop         Chrome                 NDF
# 4ft3gnwmtx   Windows Desktop             IE                  US
# bjjt8pjhuk       Mac Desktop        Firefox               other
# 87mebub9p4       Mac Desktop         Chrome                  US
# osr2jwljor       Mac Desktop         Chrome                  US
# lsw9q7uk0j       Mac Desktop         Safari                  US
# 0d01nltbrs       Mac Desktop         Safari                  US
# a1vcnhxeij       Mac Desktop         Safari                  US
# 6uh8zyj2gn       Mac Desktop        Firefox                  US
# yuuqmid2rp       Mac Desktop        Firefox                  US
# om1ss59ys8            iPhone      -unknown-                 NDF
# k6np330cm1     Other/Unknown      -unknown-                  FR
# dy3rgx56cu       Mac Desktop        Firefox                 NDF
# ju3h98ch3w            iPhone  Mobile Safari                 NDF
# v4d5rl22px   Windows Desktop         Chrome                  CA
# 2dwbwkx056     Other/Unknown      -unknown-                 NDF
# frhre329au     Other/Unknown      -unknown-                  US
# cxlg85pg1r     Other/Unknown      -unknown-                 NDF
# gdka1q5ktd       Mac Desktop         Chrome                  FR
# qdubonn3uk     Other/Unknown      -unknown-                  US
# qsibmuz9sx       Mac Desktop         Chrome                  US
# 80f7dwscrn            iPhone      -unknown-                  US
# jha93x042q       Mac Desktop         Safari                 NDF
# 7i49vnuav6       Mac Desktop        Firefox                 NDF
# al8bcetz0g       Mac Desktop         Chrome                  FR
# bjg0m5otl3     Other/Unknown      -unknown-                 NDF
# hfrl5gle36   Desktop (Other)         Chrome                  US
# tp6x3md0n4     Other/Unknown      -unknown-                  FR
# hql77nu2lk    Android Tablet      -unknown-                  US
# ...                      ...            ...                 ...
# c98s3h7kgj       Mac Desktop        Firefox                 NDF
# ytmpiwb8hj   Windows Desktop             IE                 NDF
# 3dx1jk6yk2            iPhone      -unknown-                 NDF
# hcfj07iowv   Windows Desktop         Chrome                 NDF
# l1f71f9vsj   Windows Desktop         Chrome                 NDF
# 15bj4ahmhf     Android Phone  Chrome Mobile                 NDF
# qwpybxfjdl   Desktop (Other)         Chrome                 NDF
# k4t61wuvyq     Android Phone      -unknown-                 NDF
# mhh7b52z44            iPhone      -unknown-                 NDF
# 79wk7k2k5t       Mac Desktop         Chrome                 NDF
# ftwmocvwlq   Windows Desktop        Firefox                 NDF
# rg7ayg1tob       Mac Desktop         Safari                 NDF
# 2f24umzkuv              iPad  Mobile Safari                 NDF
# or77n2ojuj       Mac Desktop         Chrome                 NDF
# 0a5bnb9bs4   Windows Desktop         Chrome                 NDF
# 6fzrn49sfn            iPhone      -unknown-                 NDF
# r0jq0devgy    Android Tablet      -unknown-                 NDF
# v5lq9bj8gv            iPhone      -unknown-                 NDF
# msucfwmlzc   Windows Desktop        Firefox                  US
# 04y8115avm            iPhone  Mobile Safari                 NDF
# omlc9iku7t       Mac Desktop         Chrome                  ES
# rf0ay567js       Mac Desktop         Chrome                 NDF
# 0k26r3mir0       Mac Desktop         Safari                  US
# 40o1ivh6cb   Windows Desktop         Chrome                 NDF
# qbxza0xojf   Windows Desktop             IE                  US
# zxodksqpep       Mac Desktop         Safari                 NDF
# mhewnxesx9   Windows Desktop         Chrome                 NDF
# 6o3arsjbb4       Mac Desktop        Firefox                 NDF
# jh95kwisub            iPhone  Mobile Safari                 NDF
# nw9fwlyb5f            iPhone      -unknown-                 NDF
#
#            channel__linked channel__local ops  channel__marketing  \
# id
# gxn3p5htnn             0.0                0.0                 0.0
# 820tgsjxq7             0.0                0.0                 0.0
# 4ft3gnwmtx             0.0                0.0                 0.0
# bjjt8pjhuk             0.0                0.0                 0.0
# 87mebub9p4             0.0                0.0                 0.0
# osr2jwljor             0.0                0.0                 0.0
# lsw9q7uk0j             0.0                0.0                 0.0
# 0d01nltbrs             0.0                0.0                 0.0
# a1vcnhxeij             0.0                0.0                 0.0
# 6uh8zyj2gn             0.0                0.0                 0.0
# yuuqmid2rp             0.0                0.0                 0.0
# om1ss59ys8             0.0                0.0                 0.0
# k6np330cm1             0.0                0.0                 0.0
# dy3rgx56cu             1.0                0.0                 0.0
# gdka1q5ktd           0.0               0.0                     0.0
# qdubonn3uk           0.0               0.0                     0.0
# qsibmuz9sx           0.0               0.0                     0.0
# 80f7dwscrn           0.0               0.0                     0.0
# jha93x042q           0.0               0.0                     0.0
# 7i49vnuav6           0.0               0.0                     0.0
# al8bcetz0g           0.0               0.0                     0.0
# bjg0m5otl3           0.0               0.0                     0.0
# hfrl5gle36           0.0               0.0                     0.0
# tp6x3md0n4           0.0               0.0                     0.0
# hql77nu2lk           0.0               0.0                     0.0
# ...                  ...               ...                     ...
# c98s3h7kgj           0.0               0.0                     0.0
# ytmpiwb8hj           0.0               0.0                     0.0
# 3dx1jk6yk2           0.0               0.0                     0.0
# hcfj07iowv           0.0               0.0                     0.0
# l1f71f9vsj           0.0               0.0                     0.0
# 15bj4ahmhf           0.0               0.0                     0.0
# qwpybxfjdl           0.0               0.0                     0.0
# k4t61wuvyq           0.0               0.0                     0.0
# mhh7b52z44           0.0               0.0                     0.0
# 79wk7k2k5t           0.0               0.0                     0.0
# ftwmocvwlq           0.0               0.0                     0.0
# rg7ayg1tob           0.0               0.0                     1.0
# 2f24umzkuv           0.0               0.0                     0.0
# or77n2ojuj           0.0               1.0                     0.0
# 0a5bnb9bs4           0.0               0.0                     0.0
# 6fzrn49sfn           0.0               0.0                     0.0
# r0jq0devgy           0.0               0.0                     0.0
# v5lq9bj8gv           0.0               0.0                     0.0
# msucfwmlzc           0.0               0.0                     0.0
# 04y8115avm           0.0               0.0                     0.0
# omlc9iku7t           0.0               0.0                     0.0
# rf0ay567js           1.0               0.0                     0.0
# 0k26r3mir0           0.0               0.0                     0.0
# 40o1ivh6cb           0.0               0.0                     0.0
# qbxza0xojf           1.0               0.0                     0.0
# zxodksqpep           1.0               0.0                     0.0
# mhewnxesx9           0.0               0.0                     0.0
# 6o3arsjbb4           0.0               0.0                     0.0
# jh95kwisub           0.0               0.0                     1.0
# nw9fwlyb5f           0.0               0.0                     0.0
#
#             channel__untracked
# id
# gxn3p5htnn                 1.0
# 820tgsjxq7                 1.0
# 4ft3gnwmtx                 1.0
# bjjt8pjhuk                 1.0
# 87mebub9p4                 1.0
# osr2jwljor                 0.0
# lsw9q7uk0j                 1.0
# 0d01nltbrs                 0.0
# a1vcnhxeij                 1.0
# 6uh8zyj2gn                 0.0
# yuuqmid2rp                 1.0
# om1ss59ys8                 1.0
# k6np330cm1                 0.0
# dy3rgx56cu                 0.0
# ju3h98ch3w                 1.0
# v4d5rl22px                 1.0
# 2dwbwkx056                 0.0
# frhre329au                 0.0
# cxlg85pg1r                 0.0
# gdka1q5ktd                 1.0
# qdubonn3uk                 0.0
# qsibmuz9sx                 0.0
# 80f7dwscrn                 1.0
# jha93x042q                 1.0
# 7i49vnuav6                 1.0
# al8bcetz0g                 1.0
# bjg0m5otl3                 1.0
# hfrl5gle36                 1.0
# tp6x3md0n4                 0.0
# hql77nu2lk                 1.0
# ...                        ...
# c98s3h7kgj                 0.0
# ytmpiwb8hj                 1.0
# 3dx1jk6yk2                 1.0
# hcfj07iowv                 0.0
# l1f71f9vsj                 0.0
# 15bj4ahmhf                 1.0
# qwpybxfjdl                 0.0
# k4t61wuvyq                 1.0
# mhh7b52z44                 1.0
# 79wk7k2k5t                 0.0
# ftwmocvwlq                 1.0
# rg7ayg1tob                 0.0
# 2f24umzkuv                 1.0
# or77n2ojuj                 0.0
# 0a5bnb9bs4                 1.0
# 6fzrn49sfn                 1.0
# r0jq0devgy                 1.0
# v5lq9bj8gv                 1.0
# msucfwmlzc                 1.0
# 04y8115avm                 1.0
# omlc9iku7t                 0.0
# rf0ay567js                 0.0
# 0k26r3mir0                 0.0
# 40o1ivh6cb                 0.0
# qbxza0xojf                 0.0
# zxodksqpep                 0.0
# mhewnxesx9                 0.0
# 6o3arsjbb4                 1.0
# jh95kwisub                 0.0
# nw9fwlyb5f                 1.0
#
# [213451 rows x 22 columns]

# %%
pd.concat
# Out:
# <function pandas.tools.merge.concat>

# %%
bnb.shape

# %%
bnb[bnb['age']<100].plot(kind='hist', y='age')

# %%
bnb[bnb['age']>1000].plot(kind='hist', y='age', bins=20)

# %%
bnb[bnb['age']>1000].age.head(10)

# %%
bnb2 = bnb[bnb['age']<1000]

bnb2[bnb2['age']>80].plot(kind='hist', y='age', bins=20)

# %%
print bnb2[bnb2['age']>80].shape
print bnb[bnb['age']>80].shape
print bnb['age'].shape
2771/213451

# %%
bnb[bnb['age']>80].head()
#there are 2771 people with ages over 80 -- looks like there are some 2014s too

# %%
bnb.age.isnull().sum()

# %%
bnb.shape

# %%
bnb.age.isnull().value_counts()

# %%
bnbA= bnb[(bnb['age']<80) & (bnb['age']>=18)]

# %%
bnbA.shape

# %%
bnbx = bnb
bnbx.shape

# %%
b_dist =bnbx[(bnbx['age']<80) & (bnbx['age']>=18)]
bnbx['age'] = bnbx.age.fillna(28)

# %%
bnbx.shape

# %%
bnbB= bnbx[(bnbx['age']<80) & (bnbx['age']>=18)]

# %%
print 'A (no fillna() and values cut 18<=x<80):'
print bnbA.shape

print 'B (values cut 18<=x<80):'
print bnbB.shape

# %%
bnbA.age.plot.hist()

# %%
bnbB.age.plot.hist()

# %%
pd.Series(bnbA.age).isnull().any()

# %%
pd.Series(bnbB.age).isnull().any()

# %% [markdown]
# ## Something Else Below

# %%
bnbA.date_first_booking.head()

# %%
bnbA['date_first_booking'] = bnbA.date_first_booking.fillna(0)

# %%
bnbA.date_first_booking.head(10)

# %%
bnbA_2 = bnbA[bnbA['date_first_booking']!=0]
#if I want to create a sub dataset that is only for people who HAVE booked

# %%
bnbA_2

# %%
bnbAx.timestamp_first_active.plot.hist()

# %%
bnbAx.language.value_counts().plot.bar()

# %%
bnbAx.country_destination.value_counts().plot.bar()

# %%
bnbAx[bnbAx['language']!='en'].country_destination.value_counts().plot.bar()

# %%
bnbAx[bnbAx['language']=='en'].country_destination.value_counts().plot.pie()

# %%
bnbAx[bnbAx['language']=='fr'].country_destination.value_counts().plot.pie()

# %%
bnbAx[bnbAx['language']=='fr'].first_browser.value_counts().plot.pie()

# %%
a = bnbAx[bnbAx['language']=='en'].first_browser.value_counts()/len(bnbAx[bnbAx['language']=='en'])
a.head()

# %%
b = bnbAx[bnbAx['language']=='fr'].first_browser.value_counts()/len(bnbAx[bnbAx['language']=='fr'])
b.head()

# %%
c = bnbAx[bnbAx['language']=='es'].first_browser.value_counts()/len(bnbAx[bnbAx['language']=='es'])
c.head()

# %%
bnbAx.first_browser.get_dummies()

# %% [markdown]
# ### Mapping features to numbers
# **columns to do:**
# first_browser
# language
# country_destination

# %%
d_bnbAx = pd.get_dummies(bnbAx['first_browser'], prefix = 'brow_')

# %%
d_bnbAx.head()

# %%
bnbAx.country_destination.value_counts()

# %%
bnbAx['country_code'] = bnbAx.country_destination.map({'other':0,'US':1,'FR':2,'IT':3,'GB':4,'ES':5,'CA':6,'DE':7,'NL':8,'AU':9,'PT':10})

# %%
bnbAx.head(5)

# %%
bnbAx.language.value_counts()

# %%
bnbAx_lang = pd.get_dummies(bnbAx.language, prefix='lang_')
bnbAx_lang.shape

# %%
bnbAx = pd.concat([bnbAx, pd.get_dummies(bnbAx['language'], prefix='lang_')])

# %%
bnb.columns
type(bnb.gender)

# %%
bnb.isnull().sum()

# %%
# gender
uk_row, uk_col = bnb[bnb['gender']=='-unknown-'].shape
m_row, m_col = bnb[bnb['gender']=='MALE'].shape
f_row, f_col = bnb[bnb['gender']=='FEMALE'].shape
o_row, o_col = bnb[bnb['gender']=='OTHER'].shape

row, col = bnb.shape

u = float(uk_row)/float(row)
m = float(m_row)/float(row)
f = float(f_row)/float(row)
o = float(o_row)/float(row)

perc = {'unknown':u, 
       'male':m,
       'female':f,
       'other':o}

print 'Accounts by Gender'
perc

# %%
bnb2 = bnb[bnb['country_destination']!='NDF']

uk_row, uk_col = bnb2[bnb2['gender']=='-unknown-'].shape
m_row, m_col = bnb2[bnb2['gender']=='MALE'].shape
f_row, f_col = bnb2[bnb2['gender']=='FEMALE'].shape
o_row, o_col = bnb2[bnb2['gender']=='OTHER'].shape

row, col = bnb2.shape

u = float(uk_row)/float(row)
m = float(m_row)/float(row)
f = float(f_row)/float(row)
o = float(o_row)/float(row)

perc = {'unknown':u, 
       'male':m,
       'female':f,
       'other':o}
print 'Bookings by Gender'
perc

# %%
row_bk, col3 = bnb2.shape
ATB = float(row_bk)/float(row)
ATB

# %% [markdown]
# ## BOOKING RATES
#
# where:
# affiliate_provider == 'facebook' --> bnb_fb
# affiliate_provider == 'meetup'

# %%
bnb_fb = bnb[bnb['affiliate_provider']=='facebook']
row_fb, col_fb = bnb_fb.shape

ATB_FB = float(row_fb)/float(row)

bnb_mu = bnb[bnb['affiliate_provider']=='meetup']
row_mu, col_mu = bnb_mu.shape

ATB_MU = float(row_mu)/float(row)

print ATB_FB
print ATB_MU

# %%
bnb.groupby('gender').count()

# %%
#timestamp first active

bnb['timestamp_first_active'][1]

# %%
#language
bnb.groupby('language')

# %%
bnb.groupby('affiliate_provider').count()

# %%
print bnb.first_affiliate_tracked.shape
print pd.Series(bnb.first_affiliate_tracked).value_counts()

# %%
pd.Series(bnb.first_affiliate_tracked).isnull().sum()

# %%
pd.Series(bnb.first_affiliate_tracked).fillna('untracked', inplace=True)

# %%
pd.Series(bnb.first_affiliate_tracked).isnull().any()

# %%
pd.Series(bnb.first_affiliate_tracked).value_counts()

# %%
# account created -- date value between 1/1/10 and 6/30/14

# %% [markdown]
# Let's think about this question: Based on observed characteristics, did a person book, and if yes, where?
