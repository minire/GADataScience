# %% [markdown]
# ## AirBnB Data evaluation
#
# Let's take a look at the data first

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
url = '/Users/jennawhite/documents/gaclass/wild_west/abnb_project/data/train_users_2.csv'

bnb = pd.read_csv(url, index_col='id')
bnb.head()
# Out:
#            date_account_created  timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28          20090319043255                NaN
# 820tgsjxq7           2011-05-25          20090523174809                NaN
# 4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#                gender   age signup_method  signup_flow language  \
# id
# gxn3p5htnn  -unknown-   NaN      facebook            0       en
# 820tgsjxq7       MALE  38.0      facebook            0       en
# 4ft3gnwmtx     FEMALE  56.0         basic            3       en
# bjjt8pjhuk     FEMALE  42.0      facebook            0       en
# 87mebub9p4  -unknown-  41.0         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
#
#            signup_app first_device_type first_browser country_destination
# id
# gxn3p5htnn        Web       Mac Desktop        Chrome                 NDF
# 820tgsjxq7        Web       Mac Desktop        Chrome                 NDF
# 4ft3gnwmtx        Web   Windows Desktop            IE                  US
# bjjt8pjhuk        Web       Mac Desktop       Firefox               other
# 87mebub9p4        Web       Mac Desktop        Chrome                  US

# %%
bnb[bnb['age']<100].plot(kind='hist', y='age')

# %%
bnb[bnb['age']>80].head()
#there are 2771 people with ages over 80 -- looks like there are some 2014s too
# Out:
#            date_account_created  timestamp_first_active date_first_booking  \
# id
# v2x0ms9c62           2010-04-11          20100411065602         2010-04-13
# 9ouah6tc30           2010-04-12          20100412231534         2010-04-12
# dc3udjfdij           2010-05-19          20100519012455         2010-06-16
# ixv5186g1h           2010-05-21          20100521070029                NaN
# umf1wdk9uc           2010-05-25          20100525155541                NaN
#
#                gender     age signup_method  signup_flow language  \
# id
# v2x0ms9c62  -unknown-  2014.0         basic            3       en
# 9ouah6tc30     FEMALE   104.0      facebook            3       en
# dc3udjfdij  -unknown-   105.0         basic            2       en
# ixv5186g1h       MALE    95.0         basic            0       en
# umf1wdk9uc     FEMALE  2014.0         basic            2       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# v2x0ms9c62             other         craigslist               untracked
# 9ouah6tc30             other         craigslist                  linked
# dc3udjfdij             other         craigslist                     omg
# ixv5186g1h            direct             direct               untracked
# umf1wdk9uc             other         craigslist               untracked
#
#            signup_app first_device_type  first_browser country_destination
# id
# v2x0ms9c62        Web   Windows Desktop        Firefox                  FR
# 9ouah6tc30        Web            iPhone  Mobile Safari                  FR
# dc3udjfdij        Web       Mac Desktop         Safari                  FR
# ixv5186g1h        Web       Mac Desktop        Firefox                 NDF
# umf1wdk9uc        Web       Mac Desktop         Safari                 NDF

# %%
bnb.columns
type(bnb.gender)
# Out:
# pandas.core.series.Series

# %%
bnb.isnull().sum()
# Out:
# date_account_created            0
# timestamp_first_active          0
# date_first_booking         124543
# gender                          0
# age                         87990
# signup_method                   0
# signup_flow                     0
# language                        0
# affiliate_channel               0
# affiliate_provider              0
# first_affiliate_tracked      6065
# signup_app                      0
# first_device_type               0
# first_browser                   0
# country_destination             0
# dtype: int64

# %%
# gender
uk_row, uk_col = bnb[bnb['gender']=='-unknown-'].shape
m_row, m_col = bnb[bnb['gender']=='MALE'].shape
f_row, f_col = bnb[bnb['gender']=='FEMALE'].shape
o_row, o_col = bnb[bnb['gender']=='OTHER'].shape

row, col = bnb.shape

u = float(uk_row)/float(row)
m = float(m_row)/float(row)
f = float(f_row)/float(row)
o = float(o_row)/float(row)

perc = {'unknown':u, 
       'male':m,
       'female':f,
       'other':o}

print 'Accounts by Gender'
perc
# Out:
# Accounts by Gender
# {'female': 0.2953417880450314,
#  'male': 0.25504682573518045,
#  'other': 0.0013211463052410154,
#  'unknown': 0.44829023991454714}

# %%
bnb2 = bnb[bnb['country_destination']!='NDF']

uk_row, uk_col = bnb2[bnb2['gender']=='-unknown-'].shape
m_row, m_col = bnb2[bnb2['gender']=='MALE'].shape
f_row, f_col = bnb2[bnb2['gender']=='FEMALE'].shape
o_row, o_col = bnb2[bnb2['gender']=='OTHER'].shape

row, col = bnb2.shape

u = float(uk_row)/float(row)
m = float(m_row)/float(row)
f = float(f_row)/float(row)
o = float(o_row)/float(row)

perc = {'unknown':u, 
       'male':m,
       'female':f,
       'other':o}
print 'Bookings by Gender'
perc
# Out:
# Bookings by Gender
# {'female': 0.3598438835650335,
#  'male': 0.31179421424393755,
#  'other': 0.0019795743915058265,
#  'unknown': 0.3263823277995231}

# %%
row_bk, col3 = bnb2.shape
ATB = float(row_bk)/float(row)
ATB
# Out:
# 0.4165265095970504

# %% [markdown]
# ## BOOKING RATES
#
# where:
# affiliate_provider == 'facebook' --> bnb_fb
# affiliate_provider == 'meetup'

# %%
bnb_fb = bnb[bnb['affiliate_provider']=='facebook']
row_fb, col_fb = bnb_fb.shape

ATB_FB = float(row_fb)/float(row)

bnb_mu = bnb[bnb['affiliate_provider']=='meetup']
row_mu, col_mu = bnb_mu.shape

ATB_MU = float(row_mu)/float(row)

print ATB_FB
print ATB_MU
# Out:
# 0.0106488140135
# 0.00162566584368

# %%
bnb.groupby('gender').count()
# Out:
#            date_account_created  timestamp_first_active  date_first_booking  \
# gender
# -unknown-                 95688                   95688               29018
# FEMALE                    63041                   63041               31993
# MALE                      54440                   54440               27721
# OTHER                       282                     282                 176
#
#              age  signup_method  signup_flow  language  affiliate_channel  \
# gender
# -unknown-  16843          95688        95688     95688              95688
# FEMALE     57713          63041        63041     63041              63041
# MALE       50677          54440        54440     54440              54440
# OTHER        228            282          282       282                282
#
#            affiliate_provider  first_affiliate_tracked  signup_app  \
# gender
# -unknown-               95688                    91783       95688
# FEMALE                  63041                    61978       63041
# MALE                    54440                    53347       54440
# OTHER                     282                      278         282
#
#            first_device_type  first_browser  country_destination
# gender
# -unknown-              95688          95688                95688
# FEMALE                 63041          63041                63041
# MALE                   54440          54440                54440
# OTHER                    282            282                  282

# %%
#timestamp first active

bnb['timestamp_first_active'][1]
# Out:
# 20090523174809

# %%
#language
bnb.groupby('language')
# Out:
# <bound method DataFrameGroupBy.apply of <pandas.core.groupby.DataFrameGroupBy object at 0x113507350>>

# %%
bnb.groupby('affiliate_provider').count()
# Out:
#                      date_account_created  timestamp_first_active  \
# affiliate_provider
# baidu                                  29                      29
# bing                                 2328                    2328
# craigslist                           3471                    3471
# daum                                    1                       1
# direct                             137426                  137426
# email-marketing                       166                     166
# facebook                             2273                    2273
# facebook-open-graph                   545                     545
# google                              51693                   51693
# gsp                                   453                     453
# meetup                                347                     347
# naver                                  52                      52
# other                               12549                   12549
# padmapper                             768                     768
# vast                                  829                     829
# wayn                                    8                       8
# yahoo                                 496                     496
# yandex                                 17                      17
#
#                      date_first_booking  gender    age  signup_method  \
# affiliate_provider
# baidu                                10      29     15             29
# bing                                833    2328   1206           2328
# craigslist                         1616    3471   2261           3471
# daum                                  1       1      0              1
# direct                            59234  137426  80404         137426
# email-marketing                      37     166     81            166
# facebook                            792    2273   1614           2273
# facebook-open-graph                 141     545    409            545
# google                            20779   51693  29738          51693
# gsp                                  37     453    186            453
# meetup                               46     347    139            347
# naver                                18      52     27             52
# other                              4663   12549   8257          12549
# padmapper                           252     768    465            768
# vast                                271     829    390            829
# wayn                                  0       8      3              8
# yahoo                               174     496    252            496
# yandex                                4      17     14             17
#
#                      signup_flow  language  affiliate_channel  \
# affiliate_provider
# baidu                         29        29                 29
# bing                        2328      2328               2328
# craigslist                  3471      3471               3471
# daum                           1         1                  1
# direct                    137426    137426             137426
# email-marketing              166       166                166
# facebook                    2273      2273               2273
# facebook-open-graph          545       545                545
# google                     51693     51693              51693
# gsp                          453       453                453
# meetup                       347       347                347
# naver                         52        52                 52
# other                      12549     12549              12549
# padmapper                    768       768                768
# vast                         829       829                829
# wayn                           8         8                  8
# yahoo                        496       496                496
# yandex                        17        17                 17
#
#                      first_affiliate_tracked  signup_app  first_device_type  \
# affiliate_provider
# baidu                                     29          29                 29
# bing                                    2261        2328               2328
# craigslist                              2990        3471               3471
# daum                                       1           1                  1
# direct                                133935      137426             137426
# email-marketing                          163         166                166
# facebook                                2201        2273               2273
# facebook-open-graph                      545         545                545
# google                                 50459       51693              51693
# gsp                                      453         453                453
# meetup                                   347         347                347
# naver                                     52          52                 52
# other                                  11909       12549              12549
# padmapper                                768         768                768
# vast                                     752         829                829
# wayn                                       8           8                  8
# yahoo                                    496         496                496
# yandex                                    17          17                 17
#
#                      first_browser  country_destination
# affiliate_provider
# baidu                           29                   29
# bing                          2328                 2328
# craigslist                    3471                 3471
# daum                             1                    1
# direct                      137426               137426
# email-marketing                166                  166
# facebook                      2273                 2273
# facebook-open-graph            545                  545
# google                       51693                51693
# gsp                            453                  453
# meetup                         347                  347
# naver                           52                   52
# other                        12549                12549
# padmapper                      768                  768
# vast                           829                  829
# wayn                             8                    8
# yahoo                          496                  496
# yandex                          17                   17

# %%
# account created -- date value between 1/1/10 and 6/30/14

# %% [markdown]
# Let's think about this question: Based on observed characteristics, did a person book, and if yes, where?
